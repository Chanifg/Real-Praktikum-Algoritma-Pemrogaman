# %%
# Condition Equal
a = 5
a == 6
# Out:
# False

# %%
# Greater than Sign

i = 6
i > 5
# Out:
# True

# %%
# Grather than Sign

i = 2
i > 5
# Out:
# False

# %%
# Inequality Sign

i = 2
i != 6
# Out:
# True

# %%
# Inequality Sign

i = 6
i != 6
# Out:
# False

# %%
# Use Equalitysign to compare the strings

"ACDC" == "Michael Jackson"
# Out:
# False

# %%
"ACDC" != "Michael Jackson"
# Out:
# True

# %%
# Compare characters

'B' > 'A'
# Out:
# True

# %%
# Compare characters

'BA' > 'AB'
# Out:
# True

# %%
"ba" >= 'ba'
# Out:
# True

# %% [markdown]
# **Branching**

# %%
# If statment example

#age = 19
age = 19

#expresion that can be true or false
if age > 18:

    #within an indent, we have the expression that is run if the condition is true
    print("you can enter")

#The statements after the if statement will run regardless if the condition is true or false
print("move on")
# Out:
# you can enter
# move on

# %% [markdown]
# Try uncommenting the age variable

# %%
# Else statement example

#age = 17
age = 19

if age > 18:
  print("You can enter")
else:
    print("go see Meat Loaf")

#print("move on")
print("move on")
# Out:
# You can enter
# move on

# %%
# Elif statement example

age = 18

if age > 18:
    print("You can enter")
elif age == 18:
    print("Go see Pink Floyd")
else:
    print("Go see Meat Loaf")

print("Move on")
# Out:
# Go see Pink Floyd
# Move on

# %%
# Condition statement example

album_year = 1983
#album_year = 1970

if album_year > 1980:
    print("Album yeaar is greater the 1980")

print('do something..')
# Out:
# Album yeaar is greater the 1980
# do something..

# %%
# Condition statement example

#album_year = 1983
album_year = 1970

if album_year > 1980:
    print("Album year is greter than 1980")
else:
    print("less than 1980")

print('do something..')
# Out:
# less than 1980
# do something..

# %% [markdown]
# **Logical Operator**

# %%
# Condition statement example

album_year = 1980

if(album_year > 1979) and (album_year < 1990):
    print("Album year was in between 1980 and 1989")

print("")
print("Do stuff..")
# Out:
# Album year was in between 1980 and 1989
#
# Do stuff..

# %%
# Condition statement example

album_year = 1978

if(album_year < 1980) or (album_year > 1989):
    print("Album was not made in the 1980's")
else:
    print("The Album was made in the 1980's")
# Out:
# Album was not made in the 1980's

# %%
# Condition statement example

albu_year = 1984

if not (album_year == '1984'):
    print("Album year is not 1984")
# Out:
# Album year is not 1984

# %% [markdown]
# **Weekly Exercise 1**

# %%
Umur = int(input("Masukan umur anda: "))
if(Umur >= 17):
    print("Anda diperbolehkan membuat SIM")
else:
    print("Anda tidak diperbolehkan membuat SIM")
# Out:
# Masukan umur anda: 23
# Anda diperbolehkan membuat SIM

# %% [markdown]
# **Weekly Exercise 2**

# %%
Nilai = int(input("Masukan Nilai Anda: "))
if(Nilai >= 90):
    print("Nilai Anda A")
elif(Nilai >= 80):
    print("Nilai Anda B+")
elif(Nilai >= 70):
    print("Nilai Anda B")
elif(Nilai >= 60):
    print("Nilai Anda C+")
elif(Nilai >= 50):
    print("Nilai Anda C")
elif(Nilai >= 40):
    print("Nilai Anda D")
else:
    print("Nilai Anda E")
# Out:
# Masukan Nilai Anda: 40
# Nilai Anda D

# %%
Nilai = int(input("Masukan Nilai Anda: "))
if(80.00 <= Nilai <= 100):
    print("Nilai Anda A")
elif(77.50 <= Nilai <= 79.99):
    print("Nilai Anda A-")
elif(75.00 <= Nilai <= 77.49):
    print("Nilai Anda A/B")
elif(72.50 <= Nilai <= 74.99):
    print("Nilai Anda B+")
elif(70.00 <= Nilai <= 72.49):
    print("Nilai Anda B")
elif(67.50 <= Nilai <= 69.99):
    print("Nilai Anda B-")
elif(65.00 <= Nilai <= 67.49):
    print("Nilai Anda B/C")
elif(62.50 <= Nilai <= 64.99):
    print("Nilai Anda C+")
elif(60.00 <= Nilai <= 62.49):
    print("Nilai Anda C")
elif(55.00 <= Nilai <= 59.99):
    print("Nilai Anda C-")
elif(50.00 <= Nilai <= 54.99):
    print("Nilai Anda C/D")
elif(45.00 <= Nilai <= 49.99):
    print("Nilai Anda D+")
elif(40.00<= Nilai <= 44.99):
    print("Nilai Anda D")
elif(Nilai < 40.00):
    print("Nilai Anda E")
else:
    print("Anda Tidak Bernilai")
# Out:
# Masukan Nilai Anda: 78
# Nilai Anda A-
